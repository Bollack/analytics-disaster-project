# %% [markdown]
# # Introduction

# %% [markdown]
# This is the first deliverable from the GAP Analytics Bootcamp. In this notebook, an exploratory data analysis was done on a dataset about declarations of disaster. We assume that the data is exclusively from the US due to the fact that the institution that gather the data is an american one, but we need to confirm this asumption. The members of the group are:
#
# - Cesar Rojas
# - Nelson Acuña
# - Daniel Troyo
#
# We will handle the following task in the notebook:
#
# - Discover the size and structure of the dataset
# - Handling empty values or notable outliers
# - List the usable attributes in the dataset
# - Visualize some relationships in the data

# %% [markdown]
# # Data Ingestion

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# Constantes
DS_PATH = "data/eccc91e3-d623-4dc3-8413-1c6164424740_DisasterDeclarations.csv"

# Setea el maximo de filas a desplegar en 8
pd.options.display.max_rows = 15
pd.options.display.max_columns = 24


# Lee el dataset
df = pd.read_csv(DS_PATH, parse_dates = True)
df.head()
# Out:
#    disaster_number ih_program_declared ia_program_declared  \
# 0                1                  No                 Yes
# 1                2                  No                 Yes
# 2                3                  No                 Yes
# 3                4                  No                 Yes
# 4                5                  No                 Yes
#
#   pa_program_declared hm_program_declared state     declaration_date  \
# 0                 Yes                 Yes    GA  1953-05-02T00:00:00
# 1                 Yes                 Yes    TX  1953-05-15T00:00:00
# 2                 Yes                 Yes    LA  1953-05-29T00:00:00
# 3                 Yes                 Yes    MI  1953-06-02T00:00:00
# 4                 Yes                 Yes    MT  1953-06-06T00:00:00
#
#   disaster_type incident_type                     title  incident_begin_date  \
# 0            DR       Tornado                   TORNADO  1953-05-02T00:00:00
# 1            DR       Tornado  TORNADO & HEAVY RAINFALL  1953-05-15T00:00:00
# 2            DR         Flood                     FLOOD  1953-05-29T00:00:00
# 3            DR       Tornado                   TORNADO  1953-06-02T00:00:00
# 4            DR         Flood                    FLOODS  1953-06-06T00:00:00
#
#      incident_end_date disaster_close_out_date declared_county_area  serialid
# 0  1953-05-02T00:00:00     1954-06-01T00:00:00                  NaN         1
# 1  1953-05-15T00:00:00     1958-01-01T00:00:00                  NaN         2
# 2  1953-05-29T00:00:00     1960-02-01T00:00:00                  NaN         3
# 3  1953-06-02T00:00:00     1956-02-01T00:00:00                  NaN         4
# 4  1953-06-06T00:00:00     1955-12-01T00:00:00                  NaN         5

# %% [markdown]
# # Some preliminary preprocessing

# %% [markdown]
# We'll delete some columns that we noticed are not useful to the general analysis.

# %%
# Delete columns
if 'serialid' in df.columns:
    df.drop(['serialid', 'title'], axis=1, inplace=True)
    

# Verify the columns were deleted
df.columns.values
# Out:
# array(['disaster_number', 'ih_program_declared', 'ia_program_declared',
#        'pa_program_declared', 'hm_program_declared', 'state',
#        'declaration_date', 'disaster_type', 'incident_type',
#        'incident_begin_date', 'incident_end_date',
#        'disaster_close_out_date', 'declared_county_area'], dtype=object)

# %% [markdown]
# Below we'll replace the "Yes" and "No" columns for boolean values

# %%
boolean_values = {"Yes": True, "No": False}
boolean_columns = ['ih_program_declared', 'ia_program_declared', 'pa_program_declared', 'hm_program_declared']

for column in boolean_columns:
    df = df.replace({column: boolean_values})
    
df.head()
# Out:
#    disaster_number  ih_program_declared  ia_program_declared  \
# 0                1                False                 True
# 1                2                False                 True
# 2                3                False                 True
# 3                4                False                 True
# 4                5                False                 True
#
#    pa_program_declared  hm_program_declared state     declaration_date  \
# 0                 True                 True    GA  1953-05-02T00:00:00
# 1                 True                 True    TX  1953-05-15T00:00:00
# 2                 True                 True    LA  1953-05-29T00:00:00
# 3                 True                 True    MI  1953-06-02T00:00:00
# 4                 True                 True    MT  1953-06-06T00:00:00
#
#   disaster_type incident_type  incident_begin_date    incident_end_date  \
# 0            DR       Tornado  1953-05-02T00:00:00  1953-05-02T00:00:00
# 1            DR       Tornado  1953-05-15T00:00:00  1953-05-15T00:00:00
# 2            DR         Flood  1953-05-29T00:00:00  1953-05-29T00:00:00
# 3            DR       Tornado  1953-06-02T00:00:00  1953-06-02T00:00:00
# 4            DR         Flood  1953-06-06T00:00:00  1953-06-06T00:00:00
#
#   disaster_close_out_date declared_county_area
# 0     1954-06-01T00:00:00                  NaN
# 1     1958-01-01T00:00:00                  NaN
# 2     1960-02-01T00:00:00                  NaN
# 3     1956-02-01T00:00:00                  NaN
# 4     1955-12-01T00:00:00                  NaN

# %% [markdown]
# We noticed that in the columns 'declaration_date', 'incident_begin_date', 'incident_end_date' the time seems to be set to 00:00:00. This might depend on the disaster, so we checked if for earthquakes (which definitely have a start and end hour) this is also the case.

# %%
df[df['incident_type'] == 'Earthquake']
# Out:
#        disaster_number  ih_program_declared  ia_program_declared  \
# 17                  19                False                 True
# 94                  96                False                 True
# 166                168                False                 True
# 521                196                False                 True
# 522                196                False                 True
# 523                196                False                 True
# 524                196                False                 True
# ...                ...                  ...                  ...
# 31185             1415                False                 True
# 31412             1505                 True                 True
# 34499             1664                 True                 True
# 34500             1664                 True                 True
# 34501             1664                 True                 True
# 34502             1664                 True                 True
# 36138             1911                False                False
#
#        pa_program_declared  hm_program_declared state     declaration_date  \
# 17                    True                 True    NV  1954-07-14T00:00:00
# 94                    True                 True    HI  1960-01-21T00:00:00
# 166                   True                 True    AK  1964-03-28T00:00:00
# 521                   True                 True    WA  1965-05-11T00:00:00
# 522                   True                 True    WA  1965-05-11T00:00:00
# 523                   True                 True    WA  1965-05-11T00:00:00
# 524                   True                 True    WA  1965-05-11T00:00:00
# ...                    ...                  ...   ...                  ...
# 31185                False                 True    NY  2002-05-16T00:00:00
# 31412                 True                 True    CA  2004-01-13T00:00:00
# 34499                 True                 True    HI  2006-10-17T00:00:00
# 34500                 True                 True    HI  2006-10-17T00:00:00
# 34501                 True                 True    HI  2006-10-17T00:00:00
# 34502                 True                 True    HI  2006-10-17T00:00:00
# 36138                 True                 True    CA  2010-05-07T00:00:00
#
#       disaster_type incident_type  incident_begin_date    incident_end_date  \
# 17               DR    Earthquake  1954-07-14T00:00:00  1954-07-14T00:00:00
# 94               DR    Earthquake  1960-01-21T00:00:00  1960-01-21T00:00:00
# 166              DR    Earthquake  1964-03-28T00:00:00  1964-03-28T00:00:00
# 521              DR    Earthquake  1965-05-11T00:00:00  1965-05-11T00:00:00
# 522              DR    Earthquake  1965-05-11T00:00:00  1965-05-11T00:00:00
# 523              DR    Earthquake  1965-05-11T00:00:00  1965-05-11T00:00:00
# 524              DR    Earthquake  1965-05-11T00:00:00  1965-05-11T00:00:00
# ...             ...           ...                  ...                  ...
# 31185            DR    Earthquake  2002-04-20T00:00:00  2002-04-20T00:00:00
# 31412            DR    Earthquake  2003-12-22T00:00:00  2004-02-06T00:00:00
# 34499            DR    Earthquake  2006-10-15T00:00:00  2007-01-15T00:00:00
# 34500            DR    Earthquake  2006-10-15T00:00:00  2007-01-15T00:00:00
# 34501            DR    Earthquake  2006-10-15T00:00:00  2007-01-15T00:00:00
# 34502            DR    Earthquake  2006-10-15T00:00:00  2007-01-15T00:00:00
# 36138            DR    Earthquake  2010-04-04T00:00:00  2010-07-04T00:00:00
#
#       disaster_close_out_date    declared_county_area
# 17        1957-08-01T00:00:00                     NaN
# 94        1961-06-09T00:00:00                     NaN
# 166       1971-06-17T00:00:00                     NaN
# 521       1968-12-17T00:00:00           King (County)
# 522       1968-12-17T00:00:00         Kitsap (County)
# 523       1968-12-17T00:00:00          Mason (County)
# 524       1968-12-17T00:00:00         Pierce (County)
# ...                       ...                     ...
# 31185     2010-12-21T00:00:00     Washington (County)
# 31412                     NaN  Santa Barbara (County)
# 34499                     NaN         Hawaii (County)
# 34500                     NaN       Honolulu (County)
# 34501                     NaN          Kauai (County)
# 34502                     NaN           Maui (County)
# 36138                     NaN       Imperial (County)
#
# [103 rows x 13 columns]

# %% [markdown]
# It seems that the hour is not set for earthquake either. So we'll do a more definitive test for the columns 'declaration_date', 'incident_begin_date', 'incident_end_date' to check if the hour is always zero and if the columns have N/A values.

# %%
def classifyUsableDates(hour):
    if not pd.isnull(hour):
        hour = hour.split('T')[1]
        if hour == "00:00:00":
            return "Zero hour"
        else:
            return "Non zero hour"
    else: 
        return "Null date"

dates_columns = ['declaration_date', 'incident_begin_date', 'incident_end_date', 'disaster_close_out_date']
hoursDF = df[dates_columns].apply(lambda x: x.apply(classifyUsableDates))
hoursDF.apply(pd.Series.value_counts, normalize=True)
# Out:
#            declaration_date  incident_begin_date  incident_end_date  \
# Null date               NaN                  NaN           0.008186
# Zero hour               1.0                  1.0           0.991814
#
#            disaster_close_out_date
# Null date                 0.310743
# Zero hour                 0.689257

# %% [markdown]
# We found that all the columns have a zero hour or a empty date (i.e. there isn't hour information in the columns). Also, 31% of the records don't have a disaster_close_out_date.

# %% [markdown]
# Now, we'll convert the columns 'declaration_date', 'incident_begin_date', 'incident_end_date' from "object" type to "datetime" type.

# %%
df[dates_columns] = df[dates_columns].apply(pd.to_datetime)
df[dates_columns]
# Out:
#       declaration_date incident_begin_date incident_end_date  \
# 0           1953-05-02          1953-05-02        1953-05-02
# 1           1953-05-15          1953-05-15        1953-05-15
# 2           1953-05-29          1953-05-29        1953-05-29
# 3           1953-06-02          1953-06-02        1953-06-02
# 4           1953-06-06          1953-06-06        1953-06-06
# 5           1953-06-09          1953-06-09        1953-06-09
# 6           1953-06-11          1953-06-11        1953-06-11
# ...                ...                 ...               ...
# 43360       2013-11-26          2013-11-17        2013-11-17
# 43361       2013-11-26          2013-11-17        2013-11-17
# 43362       2013-11-26          2013-11-17        2013-11-17
# 43363       2013-11-26          2013-11-17        2013-11-17
# 43364       2013-11-26          2013-11-17        2013-11-17
# 43365       2013-11-26          2013-11-17        2013-11-17
# 43366       2013-11-26          2013-11-17        2013-11-17
#
#       disaster_close_out_date
# 0                  1954-06-01
# 1                  1958-01-01
# 2                  1960-02-01
# 3                  1956-02-01
# 4                  1955-12-01
# 5                  1956-03-30
# 6                  1956-06-01
# ...                       ...
# 43360                     NaT
# 43361                     NaT
# 43362                     NaT
# 43363                     NaT
# 43364                     NaT
# 43365                     NaT
# 43366                     NaT
#
# [43367 rows x 4 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Initial EDA

# %% [markdown]
# We begin by describing the dataset

# %%
df.describe(include='all')
# Out:
#         disaster_number ih_program_declared ia_program_declared  \
# count      43367.000000               43367               43367
# unique              NaN                   2                   2
# top                 NaN               False               False
# freq                NaN               35896               23243
# first               NaN                 NaN                 NaN
# last                NaN                 NaN                 NaN
# mean        1862.533217                 NaN                 NaN
# std         1092.560275                 NaN                 NaN
# min            1.000000                 NaN                 NaN
# 25%         1046.000000                 NaN                 NaN
# 50%         1593.000000                 NaN                 NaN
# 75%         3107.000000                 NaN                 NaN
# max         4157.000000                 NaN                 NaN
#
#        pa_program_declared hm_program_declared  state     declaration_date  \
# count                43367               43367  43367                43367
# unique                   2                   2     59                 2366
# top                   True                True     TX  2005-09-10 00:00:00
# freq                 41972               32337   3558                  777
# first                  NaN                 NaN    NaN  1953-05-02 00:00:00
# last                   NaN                 NaN    NaN  2013-11-26 00:00:00
# mean                   NaN                 NaN    NaN                  NaN
# std                    NaN                 NaN    NaN                  NaN
# min                    NaN                 NaN    NaN                  NaN
# 25%                    NaN                 NaN    NaN                  NaN
# 50%                    NaN                 NaN    NaN                  NaN
# 75%                    NaN                 NaN    NaN                  NaN
# max                    NaN                 NaN    NaN                  NaN
#
#        disaster_type    incident_type  incident_begin_date  \
# count          43367            43367                43367
# unique             4               21                 2202
# top               DR  Severe Storm(s)  2005-08-29 00:00:00
# freq           31287            14544                 2764
# first            NaN              NaN  1953-05-02 00:00:00
# last             NaN              NaN  2013-11-17 00:00:00
# mean             NaN              NaN                  NaN
# std              NaN              NaN                  NaN
# min              NaN              NaN                  NaN
# 25%              NaN              NaN                  NaN
# 50%              NaN              NaN                  NaN
# 75%              NaN              NaN                  NaN
# max              NaN              NaN                  NaN
#
#           incident_end_date disaster_close_out_date declared_county_area
# count                 43012                   29891                43170
# unique                 2246                    1199                 2123
# top     2005-10-01 00:00:00     1994-06-30 00:00:00  Washington (County)
# freq                   2926                     408                  384
# first   1953-05-02 00:00:00     1954-06-01 00:00:00                  NaN
# last    2013-11-17 00:00:00     2013-11-20 00:00:00                  NaN
# mean                    NaN                     NaN                  NaN
# std                     NaN                     NaN                  NaN
# min                     NaN                     NaN                  NaN
# 25%                     NaN                     NaN                  NaN
# 50%                     NaN                     NaN                  NaN
# 75%                     NaN                     NaN                  NaN
# max                     NaN                     NaN                  NaN

# %% [markdown]
# Let's explore the categorical columns, or at least those which are not in the continous domain (num stats = NAN)

# %%
df.describe(include = ['object', 'bool'] )
# Out:
#        ih_program_declared ia_program_declared pa_program_declared  \
# count                43367               43367               43367
# unique                   2                   2                   2
# top                  False               False                True
# freq                 35896               23243               41972
#
#        hm_program_declared  state disaster_type    incident_type  \
# count                43367  43367         43367            43367
# unique                   2     59             4               21
# top                   True     TX            DR  Severe Storm(s)
# freq                 32337   3558         31287            14544
#
#        declared_county_area
# count                 43170
# unique                 2123
# top     Washington (County)
# freq                    384

# %% [markdown]
# We observe that the disaster_type column uses acronyms. We explore the possible values and the distributio next...

# %%
df['disaster_type'].value_counts()
# Out:
# DR    31287
# EM    11045
# FM      645
# FS      390
# Name: disaster_type, dtype: int64

# %%
df['disaster_type'].value_counts(normalize = 'True')
# Out:
# DR    0.721447
# EM    0.254687
# FM    0.014873
# FS    0.008993
# Name: disaster_type, dtype: float64

# %% [markdown]
# We learned that the possible values for disaster_type column are "DR", "EM", "FM", "FS". We reseached and found on a FEMA site HTML the meaning of these acronyms. According to https://www.fema.gov/disasters...
#
# ![FEMA%20Disaster%20Types.PNG](attachment:FEMA%20Disaster%20Types.PNG)

# %% [markdown]
# Also, later on (see "Identification of variable/constant columns per disaster_number" section) that these counts were not accurate as a single disaster might have multiple rows if it affected multiple counties.

# %% [markdown]
# ## Identification of variable/constant columns per disaster_number

# %% [markdown]
# While trying out the hist() function we made a histogram of the disaster number. However, the result wasn't the expected uniform distribution...

# %%
df['disaster_number'].hist(bins=[0,1000,2000,3000,4000])

# %% [markdown]
# After reviewing the data, we learned that there might be several rows with the same disaster_number; at first sight it seems that for a same disaster number the only column that changes is the declared_county_area, but we need to confirm this...

# %%
df[df['disaster_number'] == 263]
# Out:
#        disaster_number  ih_program_declared  ia_program_declared  \
# 22168              263                False                 True
# 22169              263                False                 True
# 22170              263                False                 True
# 22171              263                False                 True
# 22172              263                False                 True
# 22173              263                False                 True
#
#        pa_program_declared  hm_program_declared state declaration_date  \
# 22168                 True                 True    TN       1969-07-11
# 22169                 True                 True    TN       1969-07-11
# 22170                 True                 True    TN       1969-07-11
# 22171                 True                 True    TN       1969-07-11
# 22172                 True                 True    TN       1969-07-11
# 22173                 True                 True    TN       1969-07-11
#
#       disaster_type incident_type incident_begin_date incident_end_date  \
# 22168            DR         Flood          1969-07-11        1969-07-11
# 22169            DR         Flood          1969-07-11        1969-07-11
# 22170            DR         Flood          1969-07-11        1969-07-11
# 22171            DR         Flood          1969-07-11        1969-07-11
# 22172            DR         Flood          1969-07-11        1969-07-11
# 22173            DR         Flood          1969-07-11        1969-07-11
#
#       disaster_close_out_date declared_county_area
# 22168              1972-06-22        Clay (County)
# 22169              1972-06-22  Cumberland (County)
# 22170              1972-06-22     Jackson (County)
# 22171              1972-06-22       Macon (County)
# 22172              1972-06-22     Overton (County)
# 22173              1972-06-22      Sumner (County)

# %% [markdown]
# We first grouped by disaster_number and made a custom aggregation that, for each disaster_number-column combination, returns True if all the values in the column for the given disaster_number were the same.

# %%
def are_all_equal(series):
    if (pd.isna(series.values[0])): # == doesnt work as expected for NaN
        return all(pd.isna(val) for val in series.values)
    else:
        return all(val == series.values[0] for val in series.values)

dfAreSameByDisaster = df.groupby('disaster_number').aggregate(are_all_equal)
dfAreSameByDisaster
# Out:
#                  ih_program_declared  ia_program_declared  \
# disaster_number
# 1                               True                 True
# 2                               True                 True
# 3                               True                 True
# 4                               True                 True
# 5                               True                 True
# 6                               True                 True
# 7                               True                 True
# ...                              ...                  ...
# 4151                            True                 True
# 4152                            True                 True
# 4153                            True                 True
# 4154                            True                 True
# 4155                            True                 True
# 4156                            True                 True
# 4157                            True                 True
#
#                  pa_program_declared  hm_program_declared  state  \
# disaster_number
# 1                               True                 True   True
# 2                               True                 True   True
# 3                               True                 True   True
# 4                               True                 True   True
# 5                               True                 True   True
# 6                               True                 True   True
# 7                               True                 True   True
# ...                              ...                  ...    ...
# 4151                            True                 True   True
# 4152                            True                 True   True
# 4153                            True                 True   True
# 4154                            True                 True   True
# 4155                            True                 True   True
# 4156                            True                 True   True
# 4157                            True                 True   True
#
#                  declaration_date  disaster_type  incident_type  \
# disaster_number
# 1                            True           True           True
# 2                            True           True           True
# 3                            True           True           True
# 4                            True           True           True
# 5                            True           True           True
# 6                            True           True           True
# 7                            True           True           True
# ...                           ...            ...            ...
# 4151                         True           True           True
# 4152                         True           True           True
# 4153                         True           True           True
# 4154                         True           True           True
# 4155                         True           True           True
# 4156                         True           True           True
# 4157                         True           True           True
#
#                  incident_begin_date  incident_end_date  \
# disaster_number
# 1                               True               True
# 2                               True               True
# 3                               True               True
# 4                               True               True
# 5                               True               True
# 6                               True               True
# 7                               True               True
# ...                              ...                ...
# 4151                            True               True
# 4152                            True               True
# 4153                            True               True
# 4154                            True               True
# 4155                            True               True
# 4156                            True               True
# 4157                            True               True
#
#                  disaster_close_out_date  declared_county_area
# disaster_number
# 1                                   True                  True
# 2                                   True                  True
# 3                                   True                  True
# 4                                   True                  True
# 5                                   True                  True
# 6                                   True                  True
# 7                                   True                  True
# ...                                  ...                   ...
# 4151                                True                  True
# 4152                                True                 False
# 4153                                True                 False
# 4154                                True                 False
# 4155                                True                 False
# 4156                                True                 False
# 4157                                True                 False
#
# [3266 rows x 12 columns]

# %% [markdown]
# ...and then we made a similar aggregation that for each column, return True if all the disaster_numbers had True as result of the previous aggregation. It seems that the only columns that changes within a same disaster_number are state and declared_county_area.

# %%
def are_all_true(series):
    return all(val == True for val in series.values)

dsAreAlltrue = dfAreSameByDisaster.aggregate(are_all_true)
dsAreAlltrue.to_frame().T
# Out:
#    ih_program_declared  ia_program_declared  pa_program_declared  \
# 0                 True                 True                 True
#
#    hm_program_declared  state  declaration_date  disaster_type  incident_type  \
# 0                 True  False              True           True           True
#
#    incident_begin_date  incident_end_date  disaster_close_out_date  \
# 0                 True               True                     True
#
#    declared_county_area
# 0                 False

# %% [markdown]
# Finally, we defined columns lists of the 2 types of columns,so we can easily select these columns ahead.

# %%
idxConstantColsPerDisasterNum = np.insert(dsAreAlltrue[dsAreAlltrue].index.values, 0, "disaster_number")
idxVariableColsPerDisasterNum = dsAreAlltrue[dsAreAlltrue == False].index.values

idxConstantColsPerDisasterNum
# Sample on how to use
# newDS = ds[idxConstantColsPerDisasterNum]
# Out:
# array(['disaster_number', 'ih_program_declared', 'ia_program_declared',
#        'pa_program_declared', 'hm_program_declared', 'declaration_date',
#        'disaster_type', 'incident_type', 'incident_begin_date',
#        'incident_end_date', 'disaster_close_out_date'], dtype=object)

# %% [markdown]
# ## EDA - Part 2

# %% [markdown]
# Now we know that in order to count the disasters of each type we need to group by disaster_number first (and keep only the columns that are constant per disaster number).

# %%
#dfByDisasterNumber = df[idxConstantColsPerDisasterNum].groupby('disaster_number').first()
#dfByDisasterNumber

dfGrouped = df[idxConstantColsPerDisasterNum].groupby('disaster_number')
groupSizes = dfGrouped['disaster_number'].size()
dfByDisasterNumber = dfGrouped.first()
dfByDisasterNumber['affected_counties'] = groupSizes
dfByDisasterNumber
# Out:
#                  ih_program_declared  ia_program_declared  \
# disaster_number
# 1                              False                 True
# 2                              False                 True
# 3                              False                 True
# 4                              False                 True
# 5                              False                 True
# 6                              False                 True
# 7                              False                 True
# ...                              ...                  ...
# 4151                           False                False
# 4152                           False                False
# 4153                           False                False
# 4154                           False                False
# 4155                            True                False
# 4156                           False                False
# 4157                            True                False
#
#                  pa_program_declared  hm_program_declared declaration_date  \
# disaster_number
# 1                               True                 True       1953-05-02
# 2                               True                 True       1953-05-15
# 3                               True                 True       1953-05-29
# 4                               True                 True       1953-06-02
# 5                               True                 True       1953-06-06
# 6                               True                 True       1953-06-09
# 7                               True                 True       1953-06-11
# ...                              ...                  ...              ...
# 4151                            True                 True       2013-10-24
# 4152                            True                 True       2013-10-29
# 4153                            True                 True       2013-10-29
# 4154                            True                 True       2013-10-31
# 4155                            True                 True       2013-11-08
# 4156                            True                 True       2013-11-26
# 4157                           False                 True       2013-11-26
#
#                 disaster_type    incident_type incident_begin_date  \
# disaster_number
# 1                          DR          Tornado          1953-05-02
# 2                          DR          Tornado          1953-05-15
# 3                          DR            Flood          1953-05-29
# 4                          DR          Tornado          1953-06-02
# 5                          DR            Flood          1953-06-06
# 6                          DR          Tornado          1953-06-09
# 7                          DR          Tornado          1953-06-11
# ...                       ...              ...                 ...
# 4151                       DR  Severe Storm(s)          2013-09-13
# 4152                       DR            Flood          2013-09-09
# 4153                       DR            Flood          2013-07-27
# 4154                       DR  Severe Storm(s)          2013-10-04
# 4155                       DR  Severe Storm(s)          2013-10-03
# 4156                       DR  Severe Storm(s)          2013-10-02
# 4157                       DR          Tornado          2013-11-17
#
#                 incident_end_date disaster_close_out_date  affected_counties
# disaster_number
# 1                      1953-05-02              1954-06-01                  1
# 2                      1953-05-15              1958-01-01                  1
# 3                      1953-05-29              1960-02-01                  1
# 4                      1953-06-02              1956-02-01                  1
# 5                      1953-06-06              1955-12-01                  1
# 6                      1953-06-09              1956-03-30                  1
# 7                      1953-06-11              1956-06-01                  1
# ...                           ...                     ...                ...
# 4151                   2013-09-16                     NaT                  1
# 4152                   2013-09-22                     NaT                 26
# 4153                   2013-07-27                     NaT                  6
# 4154                   2013-10-05                     NaT                  7
# 4155                   2013-10-16                     NaT                 16
# 4156                   2013-10-06                     NaT                  9
# 4157                   2013-11-17                     NaT                 15
#
# [3266 rows x 11 columns]

# %% [markdown]
# Now we have accurate counts of each disaster_type

# %%
dfByDisasterNumber['disaster_type'].value_counts()
# Out:
# DR    2155
# FM     535
# EM     363
# FS     213
# Name: disaster_type, dtype: int64

# %%
dfByDisasterNumber['disaster_type'].value_counts(normalize = 'True')
# Out:
# DR    0.659829
# FM    0.163809
# EM    0.111145
# FS    0.065217
# Name: disaster_type, dtype: float64

# %% [markdown]
# Next, we create a cross tab to examine how the different disaster_type values relate to the incident_type

# %%
pd.crosstab(dfByDisasterNumber['disaster_type'], dfByDisasterNumber['incident_type'])
# Out:
# incident_type  Coastal Storm  Dam/Levee Break  Drought  Earthquake  Fire  \
# disaster_type
# DR                        15                3       10          28    48
# EM                         8                0       36           0    18
# FM                         0                0        0           0   535
# FS                         0                0        0           0   213
#
# incident_type  Fishing Losses  Flood  Freezing  Human Cause  Hurricane  \
# disaster_type
# DR                          5    708        18            2        202
# EM                          1     28         0            1        101
# FM                          0      0         0            0          0
# FS                          0      0         0            0          0
#
# incident_type  Mud/Landslide  Other  Severe Ice Storm  Severe Storm(s)  Snow  \
# disaster_type
# DR                         3     10                41              800    57
# EM                         0     17                 8               29    95
# FM                         0      0                 0                0     0
# FS                         0      0                 0                0     0
#
# incident_type  Terrorist  Tornado  Toxic Substances  Tsunami  Typhoon  Volcano
# disaster_type
# DR                     1      140                 3        4       53        4
# EM                     1       16                 4        0        0        0
# FM                     0        0                 0        0        0        0
# FS                     0        0                 0        0        0        0

# %% [markdown]
# # Visualization

# %%
dfByDisasterNumber
# Out:
#                  ih_program_declared  ia_program_declared  \
# disaster_number
# 1                              False                 True
# 2                              False                 True
# 3                              False                 True
# 4                              False                 True
# 5                              False                 True
# 6                              False                 True
# 7                              False                 True
# ...                              ...                  ...
# 4151                           False                False
# 4152                           False                False
# 4153                           False                False
# 4154                           False                False
# 4155                            True                False
# 4156                           False                False
# 4157                            True                False
#
#                  pa_program_declared  hm_program_declared declaration_date  \
# disaster_number
# 1                               True                 True       1953-05-02
# 2                               True                 True       1953-05-15
# 3                               True                 True       1953-05-29
# 4                               True                 True       1953-06-02
# 5                               True                 True       1953-06-06
# 6                               True                 True       1953-06-09
# 7                               True                 True       1953-06-11
# ...                              ...                  ...              ...
# 4151                            True                 True       2013-10-24
# 4152                            True                 True       2013-10-29
# 4153                            True                 True       2013-10-29
# 4154                            True                 True       2013-10-31
# 4155                            True                 True       2013-11-08
# 4156                            True                 True       2013-11-26
# 4157                           False                 True       2013-11-26
#
#                 disaster_type    incident_type incident_begin_date  \
# disaster_number
# 1                          DR          Tornado          1953-05-02
# 2                          DR          Tornado          1953-05-15
# 3                          DR            Flood          1953-05-29
# 4                          DR          Tornado          1953-06-02
# 5                          DR            Flood          1953-06-06
# 6                          DR          Tornado          1953-06-09
# 7                          DR          Tornado          1953-06-11
# ...                       ...              ...                 ...
# 4151                       DR  Severe Storm(s)          2013-09-13
# 4152                       DR            Flood          2013-09-09
# 4153                       DR            Flood          2013-07-27
# 4154                       DR  Severe Storm(s)          2013-10-04
# 4155                       DR  Severe Storm(s)          2013-10-03
# 4156                       DR  Severe Storm(s)          2013-10-02
# 4157                       DR          Tornado          2013-11-17
#
#                 incident_end_date disaster_close_out_date  affected_counties
# disaster_number
# 1                      1953-05-02              1954-06-01                  1
# 2                      1953-05-15              1958-01-01                  1
# 3                      1953-05-29              1960-02-01                  1
# 4                      1953-06-02              1956-02-01                  1
# 5                      1953-06-06              1955-12-01                  1
# 6                      1953-06-09              1956-03-30                  1
# 7                      1953-06-11              1956-06-01                  1
# ...                           ...                     ...                ...
# 4151                   2013-09-16                     NaT                  1
# 4152                   2013-09-22                     NaT                 26
# 4153                   2013-07-27                     NaT                  6
# 4154                   2013-10-05                     NaT                  7
# 4155                   2013-10-16                     NaT                 16
# 4156                   2013-10-06                     NaT                  9
# 4157                   2013-11-17                     NaT                 15
#
# [3266 rows x 11 columns]

# %%
dfByDisasterNumber["incident_year"] = dfByDisasterNumber["incident_begin_date"].apply(lambda x: x.year)

disasterCountPerYear = pd.crosstab(dfByDisasterNumber["incident_year"], dfByDisasterNumber["incident_type"])
disasterCountPerYear
disasterCountPerYear.plot(xticks=range(1953, 2014, 2), figsize=(20,10))

# %%
disasterCountiesAffectedPerYear = pd.crosstab(dfByDisasterNumber["incident_year"], dfByDisasterNumber["incident_type"], dfByDisasterNumber["affected_counties"], aggfunc="sum")
disasterCountiesAffectedPerYear = disasterCountiesAffectedPerYear.fillna(0)
disasterCountiesAffectedPerYear.plot(xticks=range(1953, 2014, 2), figsize=(20,10))

# %% [markdown]
# # <font color=red>Pending to Sort</font>

# %%
 df['incident_type'].value_counts().plot(kind='bar')

# %%
pd.crosstab(df['disaster_type'], df['incident_type'])
# Out:
# incident_type  Coastal Storm  Dam/Levee Break  Drought  Earthquake  Fire  \
# disaster_type
# DR                       170                3       87         103   914
# EM                       291                0     1205           0   664
# FM                         0                0        0           0   645
# FS                         0                0        0           0   390
#
# incident_type  Fishing Losses  Flood  Freezing  Human Cause  Hurricane  \
# disaster_type
# DR                         34   8334       301            2       3821
# EM                          8    286         0            4       4622
# FM                          0      0         0            0          0
# FS                          0      0         0            0          0
#
# incident_type  Mud/Landslide  Other  Severe Ice Storm  Severe Storm(s)  Snow  \
# disaster_type
# DR                         4     10              1013            13701  1302
# EM                         0    288               624              843  2135
# FM                         0      0                 0                0     0
# FS                         0      0                 0                0     0
#
# incident_type  Terrorist  Tornado  Toxic Substances  Tsunami  Typhoon  Volcano
# disaster_type
# DR                     1     1310                 3       10      115       49
# EM                     4       66                 5        0        0        0
# FM                     0        0                 0        0        0        0
# FS                     0        0                 0        0        0        0

# %% [markdown]
# Let's remove useless columns.

# %%
dfByDesasterNumber = df.copy()
dfByDesasterNumber.drop(['state', 'declared_county_area'], axis=1, inplace=True)

# %%
dfByDesasterNumber.groupby('disaster_number').count()
# Out:
#                  ih_program_declared  ia_program_declared  \
# disaster_number
# 1                                  1                    1
# 2                                  1                    1
# 3                                  1                    1
# 4                                  1                    1
# 5                                  1                    1
# 6                                  1                    1
# 7                                  1                    1
# ...                              ...                  ...
# 4151                               1                    1
# 4152                              26                   26
# 4153                               6                    6
# 4154                               7                    7
# 4155                              16                   16
# 4156                               9                    9
# 4157                              15                   15
#
#                  pa_program_declared  hm_program_declared  declaration_date  \
# disaster_number
# 1                                  1                    1                 1
# 2                                  1                    1                 1
# 3                                  1                    1                 1
# 4                                  1                    1                 1
# 5                                  1                    1                 1
# 6                                  1                    1                 1
# 7                                  1                    1                 1
# ...                              ...                  ...               ...
# 4151                               1                    1                 1
# 4152                              26                   26                26
# 4153                               6                    6                 6
# 4154                               7                    7                 7
# 4155                              16                   16                16
# 4156                               9                    9                 9
# 4157                              15                   15                15
#
#                  disaster_type  incident_type  incident_begin_date  \
# disaster_number
# 1                            1              1                    1
# 2                            1              1                    1
# 3                            1              1                    1
# 4                            1              1                    1
# 5                            1              1                    1
# 6                            1              1                    1
# 7                            1              1                    1
# ...                        ...            ...                  ...
# 4151                         1              1                    1
# 4152                        26             26                   26
# 4153                         6              6                    6
# 4154                         7              7                    7
# 4155                        16             16                   16
# 4156                         9              9                    9
# 4157                        15             15                   15
#
#                  incident_end_date  disaster_close_out_date
# disaster_number
# 1                                1                        1
# 2                                1                        1
# 3                                1                        1
# 4                                1                        1
# 5                                1                        1
# 6                                1                        1
# 7                                1                        1
# ...                            ...                      ...
# 4151                             1                        0
# 4152                            26                        0
# 4153                             6                        0
# 4154                             7                        0
# 4155                            16                        0
# 4156                             9                        0
# 4157                            15                        0
#
# [3266 rows x 10 columns]

# %%
#dfByDesasterNumber.groupby(['disaster_number', 'incident_begin_date']).count().resample('M').count()
dfByDesasterNumber.groupby('incident_begin_date').count().resample('Y').count().plot()

# %% [markdown]
# Pending tasks:
#
# - Parse booleans and dates
# - See which kind of disasters and in which states the duration is the longest
# - See relationship between disaster/state/date and period of time between incident_end and disaster_close_date
# - See relationship between disaster/date/period and declaration of assistance programs

# %%
#f['Counts'] = df.groupby(['Color'])['Value'].transform('count')
dfState = df.copy()
#pd.value_counts(horsekick['guardCorps'].values, sort=False)
dfState = dfState.groupby('state')['incident_type'].value_counts()
dfState['count'] = dfState.to_frame('counts')
dfState['count']
#dfState.groupby('state')['incident_type'].value_counts()
#dfState
# Out:
# incident_type
#                             counts
# state incident_...
# Name: incident_type, dtype: object

# %%
dfState['Duration'] = abs(dfState['incident_begin_date'] - dfState['incident_end_date'])
dfState['Duration'].value_counts()
# Out:
# 0 days       8594
# 33 days      2816
# 2 days       2062
# 1 days       1813
# 4 days       1625
# 13 days      1465
# 3 days       1348
#              ...
# 72 days         1
# 258 days        1
# 81 days         1
# 5117 days       1
# 242 days        1
# 152 days        1
# 59 days         1
# Name: Duration, Length: 138, dtype: int64

# %%
dfState.groupby('state')['Duration'].count().sort_values(ascending = False)
#fState.sort_values(by='Duration', ascending = False)
# Out:
# state
# TX    3523
# MO    2041
# VA    1939
# KY    1809
# OK    1691
# IA    1365
# LA    1314
#       ...
# AS      50
# DE      43
# FM      31
# MP      29
# DC      19
# GU      12
# PW       6
# Name: Duration, Length: 59, dtype: int64

# %%
df.groupby(['state','incident_type']).state.count().plot.barh(figsize=(15,75))

# %%
dfStateGraphic = dfState[['state','incident_type']]
dfStateGraphic
#ig, ax = plt.subplots()
#m = ax.imshow(dfStateGraphic)
# Out:
#       state incident_type
# 0        GA       Tornado
# 1        TX       Tornado
# 2        LA         Flood
# 3        MI       Tornado
# 4        MT         Flood
# 5        MI       Tornado
# 6        MA       Tornado
# ...     ...           ...
# 43360    IL       Tornado
# 43361    IL       Tornado
# 43362    IL       Tornado
# 43363    IL       Tornado
# 43364    IL       Tornado
# 43365    IL       Tornado
# 43366    IL       Tornado
#
# [43367 rows x 2 columns]

# %%
#boolean_values = {"Yes": True, "No": False}
numeric_values = {'Tornado':1, 'Flood':2, 'Fire':3, 'Other':21, 'Earthquake':4, 'Hurricane':5,
       'Volcano':6, 'Severe Storm(s)':7, 'Tsunami':8, 'Toxic Substances':9,
       'Typhoon':10, 'Drought':11, 'Dam/Levee Break':12, 'Snow':13,
       'Severe Ice Storm':14, 'Mud/Landslide':15, 'Freezing':16, 'Coastal Storm':17,
       'Fishing Losses':18, 'Human Cause':19, 'Terrorist':20}
numeric_column = ['incident_type']

for column in numeric_column:
    dfStateGraphic = dfStateGraphic.replace({column: numeric_values})
    

#dfStateGraphic['incident_type'].unique()

# %%
dfStateGraphic['state']
#fig, ax = plt.subplots()
#m = ax.imshow(dfStateGraphic)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in get_value(self, series, key)
#     999             try:
# -> 1000                 return libindex.get_value_at(s, k)
#    1001             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/src\util.pxd in util.get_value_at()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-179-183fd79f05f4> in <module>()
# ----> 1 dfStateGraphic['state']
#       2 #fig, ax = plt.subplots()
#       3 #m = ax.imshow(dfStateGraphic)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     764         key = com._apply_if_callable(key, self)
#     765         try:
# --> 766             result = self.index.get_value(self, key)
#     767
#     768             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in get_value(self, series, key)
#    1006                     raise InvalidIndexError(key)
#    1007                 else:
# -> 1008                     raise e1
#    1009             except Exception:  # pragma: no cover
#    1010                 raise e1
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in get_value(self, series, key)
#     990
#     991         try:
# --> 992             return self._engine.get_value(s, k)
#     993         except KeyError as e1:
#     994             try:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# KeyError: 'state'
